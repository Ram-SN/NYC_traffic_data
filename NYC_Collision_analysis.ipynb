# %%
import cartoframes
from cartoframes.auth import set_default_credentials
from cartoframes.viz import Map, Layer
import pandas as pd
import numpy as np
import geopandas as gpd
import requests
import json
from autocensus import Query #Library from Socrata to gather ACS Data
from cartoframes.data.services import Geocoding
set_default_credentials(
    base_url='https://usignite-admin.carto.com/',
    api_key='81c922dc336bd82103d92a768816a4567c444909'
)
import geopandas as gpd
from shapely import wkt
from cartoframes.data.observatory import Catalog, Variable, Geography, Dataset
from cartoframes.data.services import Geocoding
from geopandas import GeoDataFrame, points_from_xy

# %%
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_csv("Motor_Vehicle_Collisions_-_Crashes.csv")
# Out:
# C:\Users\Ram\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df1.head()
# Out:
#    CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  01/16/2013      12:26  MANHATTAN    10022  40.759620 -73.961965
# 1  02/08/2013      15:35     QUEENS    11378  40.726496 -73.914677
# 2  02/12/2013       9:17      BRONX    10468  40.869659 -73.898917
# 3  01/17/2013      19:20   BROOKLYN    11234  40.633277 -73.921616
# 4  02/11/2013      17:45   BROOKLYN    11216  40.678723 -73.952987
#
#                          LOCATION                    ON STREET NAME  \
# 0  POINT (-73.9619648 40.7596199)  EAST 59 STREET
# 1  POINT (-73.9146771 40.7264956)  56 STREET
# 2  POINT (-73.8989172 40.8696589)  RESERVOIR AVENUE
# 3   POINT (-73.9216165 40.633277)  AVENUE H
# 4   POINT (-73.9529869 40.678723)  ATLANTIC AVENUE
#
#                   CROSS STREET NAME OFF STREET NAME  \
# 0  1 AVENUE                                     NaN
# 1  55 DRIVE                                     NaN
# 2  WEST 195 STREET                              NaN
# ...

# %%
df1.dtypes
# Out:
# CRASH DATE                        object
# CRASH TIME                        object
# BOROUGH                           object
# ZIP CODE                          object
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED        float64
# NUMBER OF PERSONS KILLED         float64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# ...

# %%
gdf = gpd(df1, geometry=points_from_xy(df1['LONGITUDE'], df1['LATITUDE']))
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-ef445133ea50> in <module>
# ----> 1 gdf = gpd(df1, geometry=points_from_xy(df1['LONGITUDE'], df1['LATITUDE']))
#       2 gdf.head()
#
# TypeError: 'module' object is not callable

# %%
gdf = gpd.GeoDataFrame(df1, geometry=points_from_xy(df1.LONGITUDE, df1.LATITUDE))

# %%
gdf = gpd.GeoDataFrame(gdf, geometry='geometry', crs={'init': 'epsg:4326'})
# Out:
# C:\Users\Ram\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
gdf.head()
# Out:
#    CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  01/16/2013      12:26  MANHATTAN    10022  40.759620 -73.961965
# 1  02/08/2013      15:35     QUEENS    11378  40.726496 -73.914677
# 2  02/12/2013       9:17      BRONX    10468  40.869659 -73.898917
# 3  01/17/2013      19:20   BROOKLYN    11234  40.633277 -73.921616
# 4  02/11/2013      17:45   BROOKLYN    11216  40.678723 -73.952987
#
#                          LOCATION                    ON STREET NAME  \
# 0  POINT (-73.9619648 40.7596199)  EAST 59 STREET
# 1  POINT (-73.9146771 40.7264956)  56 STREET
# 2  POINT (-73.8989172 40.8696589)  RESERVOIR AVENUE
# 3   POINT (-73.9216165 40.633277)  AVENUE H
# 4   POINT (-73.9529869 40.678723)  ATLANTIC AVENUE
#
#                   CROSS STREET NAME OFF STREET NAME  \
# 0  1 AVENUE                                     NaN
# 1  55 DRIVE                                     NaN
# 2  WEST 195 STREET                              NaN
# ...

# %%
gdf = gdf[gdf['geometry'].notna()]
