# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
from matplotlib import pyplot as plt

# %%
df1 = pd.read_csv("Traffic_Volume_Counts__2011-2012_.csv")

# %%
df1 = df1.rename({'GIS ID': 'Segment ID'}, axis=1)

# %%
df1.head()
# Out:
#    ID  Segment ID  Roadway Name         From                To Direction  \
# 0   1       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 1   2       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 2   3       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 3   4       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 4   5       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
#
#          Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  3:00-4:00AM  \
# 0  01/09/2012             20           10           11           14
# 1  01/10/2012             21           16            8            6
# 2  01/11/2012             27           14            6            5
# 3  01/12/2012             22            7            7            8
# 4  01/13/2012             31           17            7            5
#
#    4:00-5:00AM  5:00-6:00AM  6:00-7:00AM  7:00-8:00AM  8:00-9:00AM  \
# ...

# %%
df2 = pd.read_csv("Traffic_Volume_Counts__2012-2013_.csv")

# %%
df2.head()
# Out:
#    ID  Segment ID  Roadway Name        From            To Direction  \
# 0   1        2153  HUGUENOT AVE  WOODROW RD  STAFFORD AVE        NB
# 1   1        2153  HUGUENOT AVE  WOODROW RD  STAFFORD AVE        NB
# 2   1        2153  HUGUENOT AVE  WOODROW RD  STAFFORD AVE        NB
# 3   1        2153  HUGUENOT AVE  WOODROW RD  STAFFORD AVE        NB
# 4   1        2153  HUGUENOT AVE  WOODROW RD  STAFFORD AVE        NB
#
#          Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  3:00-4:00AM  \
# 0  02/02/2013            106           74         45.0         29.0
# 1  02/03/2013            109           74         55.0         37.0
# 2  02/04/2013             36           28         11.0         16.0
# 3  02/05/2013             42           28         16.0         12.0
# 4  02/06/2013             35           38         12.0         14.0
#
#    4:00-5:00AM  5:00-6:00AM  6:00-7:00AM  7:00-8:00AM  8:00-9:00AM  \
# 0           29         45.0           71        145.0        213.0
# ...

# %%
df3 = pd.read_csv("Traffic_Volume_Counts__2014-2018_.csv")

# %%
df3.head()
# Out:
#    ID  Segment ID            Roadway Name             From                To  \
# 0   2       70376                3 Avenue  East 154 Street   East 155 Street
# 1   2       70376                3 Avenue  East 155 Street   East 154 Street
# 2  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
# 3  56      176365  Bedford Park Boulevard  Grand Concourse  Valentine Avenue
# 4  62      147673                Broadway  West 242 Street        240 Street
#
#   Direction        Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  3:00-4:00AM  \
# 0        NB  09/13/2014          204.0        177.0        133.0        126.0
# 1        SB  09/13/2014          140.0         51.0        128.0        116.0
# 2        EB  09/13/2014           94.0         73.0         65.0         61.0
# 3        WB  09/13/2014           88.0         82.0         75.0         60.0
# 4        SB  09/13/2014          255.0        209.0        149.0        148.0
#
# ...

# %%
pdList = [df1, df2, df3]  # List of your dataframes
new_df = pd.concat(pdList)

# %%
new_df.head()
# Out:
#    ID  Segment ID  Roadway Name         From                To Direction  \
# 0   1       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 1   2       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 2   3       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 3   4       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 4   5       15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
#
#          Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  3:00-4:00AM  \
# 0  01/09/2012           20.0         10.0         11.0         14.0
# 1  01/10/2012           21.0         16.0          8.0          6.0
# 2  01/11/2012           27.0         14.0          6.0          5.0
# 3  01/12/2012           22.0          7.0          7.0          8.0
# 4  01/13/2012           31.0         17.0          7.0          5.0
#
#    4:00-5:00AM  5:00-6:00AM  6:00-7:00AM  7:00-8:00AM  8:00-9:00AM  \
# ...

# %%
df1.shape
# Out:
# (3393, 31)

# %%
df2.shape
# Out:
# (5945, 31)

# %%
df3.shape
# Out:
# (21448, 31)

# %%
new_df.shape
# Out:
# (30786, 31)

# %%
new_df.dtypes
# Out:
# ID                 int64
# GIS ID           float64
# Roadway Name      object
# From              object
# To                object
# Direction         object
# Date              object
# 12:00-1:00 AM    float64
# 1:00-2:00AM      float64
# 2:00-3:00AM      float64
# 3:00-4:00AM      float64
# 4:00-5:00AM      float64
# 5:00-6:00AM      float64
# 6:00-7:00AM      float64
# 7:00-8:00AM      float64
# 8:00-9:00AM      float64
# 9:00-10:00AM     float64
# 10:00-11:00AM    float64
# 11:00-12:00PM    float64
# 12:00-1:00PM     float64
# 1:00-2:00PM      float64
# 2:00-3:00PM      float64
# 3:00-4:00PM      float64
# 4:00-5:00PM      float64
# 5:00-6:00PM      float64
# 6:00-7:00PM      float64
# 7:00-8:00PM      float64
# 8:00-9:00PM      float64
# 9:00-10:00PM     float64
# 10:00-11:00PM    float64
# 11:00-12:00AM    float64
# Segment ID       float64
# dtype: object

# %%
new_df['year'] = pd.DatetimeIndex(new_df['Date']).year
# df['month'] = pd.DatetimeIndex(df['ArrivalDate']).month

# %%
new_df
# Out:
#         ID  Segment ID      Roadway Name            From                To  \
# 0        1       15540      BEACH STREET     UNION PLACE  VAN DUZER STREET
# 1        2       15540      BEACH STREET     UNION PLACE  VAN DUZER STREET
# 2        3       15540      BEACH STREET     UNION PLACE  VAN DUZER STREET
# 3        4       15540      BEACH STREET     UNION PLACE  VAN DUZER STREET
# 4        5       15540      BEACH STREET     UNION PLACE  VAN DUZER STREET
# ...    ...         ...               ...             ...               ...
# 21443  366       26557  Mc Donald Avenue  Elmwood Avenue         47 Street
# 21444  366       26557  Mc Donald Avenue  Elmwood Avenue         47 Street
# 21445  367       42098      Utica Avenue      Lenox Road  Linden Boulevard
# 21446  367       42098      Utica Avenue      Lenox Road  Linden Boulevard
# 21447  368       37379    Madison Avenue  East 73 Street    East 74 Street
#
# ...

# %%
new_df[(new_df['Segment ID']  == 9014615)&(new_df['year']  == 2014 ) ]
# Out:
#       ID  Segment ID       Roadway Name                From  \
# 27   125     9014615  East Fordham Road  Southern Boulevard
# 99   125     9014615  East Fordham Road  Southern Boulevard
# 171  125     9014615  East Fordham Road  Southern Boulevard
# 242  125     9014615  East Fordham Road  Southern Boulevard
# 314  125     9014615  East Fordham Road  Southern Boulevard
# 387  125     9014615  East Fordham Road  Southern Boulevard
# 458  125     9014615  East Fordham Road  Southern Boulevard
# 563  125     9014615  East Fordham Road  Southern Boulevard
# 720  125     9014615  East Fordham Road  Southern Boulevard
#
#                       To Direction        Date  12:00-1:00 AM  1:00-2:00AM  \
# 27   Bronx River Parkway        WB  09/13/2014          952.0        816.0
# 99   Bronx River Parkway        WB  09/14/2014          880.0        776.0
# 171  Bronx River Parkway        WB  09/15/2014          486.0        272.0
# ...

# %%
test_df = new_df.groupby(["Segment ID","year"]).mean()

# %%
test_df
# Out:
#                     ID  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  3:00-4:00AM  \
# Segment ID year
# 202        2014  200.0     305.000000   222.000000   137.000000   138.000000
# 646        2012  779.5      28.250000    25.375000    19.000000    16.375000
# 1416       2015  290.0      61.722222    35.833333    19.388889    17.388889
# 1421       2012  670.5      53.750000    30.250000    21.750000    19.000000
# 1883       2012  686.0      57.000000    30.500000    19.000000     6.500000
# ...                ...            ...          ...          ...          ...
# 9014615    2014  125.0     652.777778   473.777778   337.000000   252.888889
# 9014764    2014  135.0    1592.222222  1049.111111   798.888889   706.444444
# 9017020    2014    5.0     370.000000   260.555556   192.888889   169.555556
# 9017037    2014  255.0     174.222222   111.333333    78.555556    68.000000
# 9017039    2014  255.0     260.777778   166.888889   125.333333   103.888889
#
# ...

# %%
test_df = test_df.sort_values(by=['Segment ID','year'], ascending=[True, True])

# %%
test_df.drop('ID', axis=1, inplace=True)

# %%
test_df
# Out:
#                  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  3:00-4:00AM  \
# Segment ID year
# 202        2014     305.000000   222.000000   137.000000   138.000000
# 646        2012      28.250000    25.375000    19.000000    16.375000
# 1416       2015      61.722222    35.833333    19.388889    17.388889
# 1421       2012      53.750000    30.250000    21.750000    19.000000
# 1883       2012      57.000000    30.500000    19.000000     6.500000
# ...                        ...          ...          ...          ...
# 9014615    2014     652.777778   473.777778   337.000000   252.888889
# 9014764    2014    1592.222222  1049.111111   798.888889   706.444444
# 9017020    2014     370.000000   260.555556   192.888889   169.555556
# 9017037    2014     174.222222   111.333333    78.555556    68.000000
# 9017039    2014     260.777778   166.888889   125.333333   103.888889
#
#                  4:00-5:00AM  5:00-6:00AM  6:00-7:00AM  7:00-8:00AM  \
# Segment ID year
# ...

# %%
test_df['total'] = test_df.sum(axis=1)

# %%
test_df
# Out:
#                  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  3:00-4:00AM  \
# Segment ID year
# 202        2014     305.000000   222.000000   137.000000   138.000000
# 646        2012      28.250000    25.375000    19.000000    16.375000
# 1416       2015      61.722222    35.833333    19.388889    17.388889
# 1421       2012      53.750000    30.250000    21.750000    19.000000
# 1883       2012      57.000000    30.500000    19.000000     6.500000
# ...                        ...          ...          ...          ...
# 9014615    2014     652.777778   473.777778   337.000000   252.888889
# 9014764    2014    1592.222222  1049.111111   798.888889   706.444444
# 9017020    2014     370.000000   260.555556   192.888889   169.555556
# 9017037    2014     174.222222   111.333333    78.555556    68.000000
# 9017039    2014     260.777778   166.888889   125.333333   103.888889
#
#                  4:00-5:00AM  5:00-6:00AM  6:00-7:00AM  7:00-8:00AM  \
# Segment ID year
# ...

# %%
new_df[(new_df['Segment ID']  == 1883)]
# Out:
#         ID  Segment ID Roadway Name            From              To Direction  \
# 684    684        1883  FOSTER ROAD   RAMONA AVENUE  RATHBUN AVENUE        NB
# 688    688        1883  FOSTER ROAD   RAMONA AVENUE  RATHBUN AVENUE        SB
# 9709   296        1883  FOSTER ROAD  RATHBUN AVENUE   RAMONA AVENUE        NB
# 9710   296        1883  FOSTER ROAD  RATHBUN AVENUE   RAMONA AVENUE        SB
# 9787   296        1883  FOSTER ROAD  RATHBUN AVENUE   RAMONA AVENUE        NB
# 9788   296        1883  FOSTER ROAD  RATHBUN AVENUE   RAMONA AVENUE        SB
# 9865   296        1883  FOSTER ROAD  RATHBUN AVENUE   RAMONA AVENUE        NB
# 9866   296        1883  FOSTER ROAD  RATHBUN AVENUE   RAMONA AVENUE        SB
# 9943   296        1883  FOSTER ROAD  RATHBUN AVENUE   RAMONA AVENUE        NB
# 9944   296        1883  FOSTER ROAD  RATHBUN AVENUE   RAMONA AVENUE        SB
# 10021  296        1883  FOSTER ROAD  RATHBUN AVENUE   RAMONA AVENUE        NB
# ...
